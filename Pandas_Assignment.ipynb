# %% [markdown]
# <a href="https://colab.research.google.com/github/Navyareddy1124/Python_Frameworks/blob/main/Pandas_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
sales_data=pd.read_csv(r'/content/drive/MyDrive/CSV files - KSRD/Advanced_Dirty_Sales_Dataset.csv')

# %%
sales_data.head(10)
# Out:
#    OrderID  CustomerID CustomerName   Product     Category Quantity    Price  \
# 0    44770        8192  @ charlie !  Keyboard  Electronics        1  $870.54
# 1    23355        9138  @ charlie !   Monitor  Electronics        5  $144.02
# 2    75847        4098  @ charlie !    Laptop  Accessories        3  $557.79
# 3    95176        2391      @ eva !   Monitor  Electronics        5   $552.2
# 4     1854        8842      @ eva !    Laptop  Accessories        4   $411.2
# 5    56788        6935    @ david !   Monitor  Electronics        1  $415.12
# 6    63473        2787      @ bob !    Tablet  Electronics        3   $677.7
# 7    79506        3389    @ alice !     Phone  Accessories        9  $674.73
# 8    55148        1287    @ david !    Laptop  Accessories        2  $330.38
# 9    24564        3745      @ bob !    Tablet  Accessories        8  $686.34
#
#           OrderDate             City Region  Returned TotalAmount
# ...

# %%
demo_sales=pd.read_csv(r"/content/drive/MyDrive/CSV files - KSRD/Advanced_Dirty_Demographics_Dataset.csv")

# %%
demo_sales.head()
# Out:
#    CustomerID CustomerName         City Region  Age  Gender IncomeBracket  \
# 0        3461          EVA  Los Angeles   West   41   male!          $LOW
# 1        1755      CHARLIE      Chicago   West   48   male!         $HIGH
# 2        1693          BOB      Phoenix   East   21  femle!       $MIDDEL
# 3        9880          BOB      Houston   West   58  femle!       $MIDDEL
# 4        2529          BOB  Los Angeles  North   26  femle!       $MIDDEL
#
#   MaritalStatus
# 0     married##
# 1     married##
# 2     married##
# 3    divorced##
# 4    divorced##

# %%
 #Load the dataset and print the shape, column names, and data types
shape=sales_data.shape
print(shape)                    #shape
print(sales_data.columns)       #column names
print(sales_data.dtypes)        #data types
# Out:
# (100100, 12)
# Index(['OrderID', 'CustomerID', 'CustomerName', 'Product', 'Category',
#        'Quantity', 'Price', 'OrderDate', 'City', 'Region', 'Returned',
#        'TotalAmount'],
#       dtype='object')
# OrderID          int64
# CustomerID       int64
# CustomerName    object
# Product         object
# Category        object
# Quantity        object
# Price           object
# OrderDate       object
# City            object
# Region          object
# Returned          bool
# TotalAmount     object
# dtype: object

# %%
#Show the first 10 and last 10 rows of the dataset.
sales_data.head(10)          # first 10 rows
# Out:
#    OrderID  CustomerID CustomerName   Product     Category Quantity    Price  \
# 0    44770        8192  @ charlie !  Keyboard  Electronics        1  $870.54
# 1    23355        9138  @ charlie !   Monitor  Electronics        5  $144.02
# 2    75847        4098  @ charlie !    Laptop  Accessories        3  $557.79
# 3    95176        2391      @ eva !   Monitor  Electronics        5   $552.2
# 4     1854        8842      @ eva !    Laptop  Accessories        4   $411.2
# 5    56788        6935    @ david !   Monitor  Electronics        1  $415.12
# 6    63473        2787      @ bob !    Tablet  Electronics        3   $677.7
# 7    79506        3389    @ alice !     Phone  Accessories        9  $674.73
# 8    55148        1287    @ david !    Laptop  Accessories        2  $330.38
# 9    24564        3745      @ bob !    Tablet  Accessories        8  $686.34
#
#           OrderDate             City Region  Returned TotalAmount
# ...

# %%
sales_data.tail(10)
# Out:
#         OrderID  CustomerID CustomerName   Product     Category Quantity  \
# 100090    87473        6459      @ eva !     Phone  Electronics        7
# 100091    46252        4130      @ bob !     Phone  Accessories        7
# 100092     6769        5466      @ eva !  Keyboard  Accessories        3
# 100093    29838        8422      @ eva !   Monitor          NaN        8
# 100094    40937        2341      @ eva !    Tablet  Accessories        4
# 100095    95426        5376    @ alice !  Keyboard  Electronics        2
# 100096    77181        6047    @ alice !  Keyboard  Accessories        5
# 100097     7354        2439      @ bob !    Laptop  Electronics        8
# 100098    52126        2810    @ alice !  Keyboard  Electronics        7
# 100099    80766        5705    @ david !    Tablet  Electronics        1
#
#            Price         OrderDate             City Region  Returned  \
# 100090    $971.5        12/10/2023      PHOENIX#123  South     False
# ...

# %%
#Convert OrderDate to datetime
sales_data['OrderDate'] = pd.to_datetime(sales_data['OrderDate'], errors='coerce')
print(sales_data.dtypes)
# Out:
# /tmp/ipython-input-437056762.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   sales_data['OrderDate'] = pd.to_datetime(sales_data['OrderDate'], errors='coerce')
# OrderID                  int64
# CustomerID               int64
# CustomerName            object
# Product                 object
# Category                object
# Quantity                object
# Price                   object
# OrderDate       datetime64[ns]
# City                    object
# Region                  object
# Returned                  bool
# TotalAmount             object
# dtype: object

# %%
#Display the total number of unique customers.
unique_customers=sales_data["CustomerID"].nunique()
print(unique_customers)
# Out:
# 8999

# %%
# Show all unique product categories and count them.
unique_categories = sales_data["Category"].unique()
print(unique_categories)
print("Count of unique categories:", len(unique_categories))
# Out:
# ['Electronics' 'Accessories' nan]
# Count of unique categories: 3

# %%
# Filter all orders made in the city of "Los Angeles
los_angles_orders=sales_data[sales_data["City"]=="Los Angeles"]
print(los_angles_orders)
# Out:
# Empty DataFrame
# Columns: [OrderID, CustomerID, CustomerName, Product, Category, Quantity, Price, OrderDate, City, Region, Returned, TotalAmount]
# Index: []

# %%
sales_data['Quantity'] = pd.to_numeric(sales_data['Quantity'], errors='coerce')
count=sales_data[sales_data["Quantity"] > 5]
print(count)
# Out:
#         OrderID  CustomerID CustomerName   Product     Category  Quantity  \
# 7         79506        3389    @ alice !     Phone  Accessories       9.0
# 9         24564        3745      @ bob !    Tablet  Accessories       8.0
# 13        69640        1481      @ bob !     Phone  Accessories       6.0
# 17        23495        1514      @ bob !    Tablet  Electronics       9.0
# 18        86339        3999      @ eva !    Laptop  Electronics       9.0
# ...         ...         ...          ...       ...          ...       ...
# 100090    87473        6459      @ eva !     Phone  Electronics       7.0
# 100091    46252        4130      @ bob !     Phone  Accessories       7.0
# 100093    29838        8422      @ eva !   Monitor          NaN       8.0
# 100097     7354        2439      @ bob !    Laptop  Electronics       8.0
# 100098    52126        2810    @ alice !  Keyboard  Electronics       7.0
#
#            Price  OrderDate             City Region  Returned TotalAmount
# ...

# %%
#Add a new column UnitTotal = Quantity * Price and compare with TotalAmount.
sales_data['Price'] = sales_data['Price'].str.replace('$', '', regex=False).astype(float)
sales_data['UnitTotal'] = sales_data['Quantity'] * sales_data['Price']
print(sales_data)
# Out:
#         OrderID  CustomerID CustomerName   Product     Category  Quantity  \
# 0         44770        8192  @ charlie !  Keyboard  Electronics       1.0
# 1         23355        9138  @ charlie !   Monitor  Electronics       5.0
# 2         75847        4098  @ charlie !    Laptop  Accessories       3.0
# 3         95176        2391      @ eva !   Monitor  Electronics       5.0
# 4          1854        8842      @ eva !    Laptop  Accessories       4.0
# ...         ...         ...          ...       ...          ...       ...
# 100095    95426        5376    @ alice !  Keyboard  Electronics       2.0
# 100096    77181        6047    @ alice !  Keyboard  Accessories       5.0
# 100097     7354        2439      @ bob !    Laptop  Electronics       8.0
# 100098    52126        2810    @ alice !  Keyboard  Electronics       7.0
# 100099    80766        5705    @ david !    Tablet  Electronics       1.0
#
#           Price  OrderDate             City Region  Returned TotalAmount  \
# ...

# %%
sales_data['TotalAmount'] = pd.to_numeric(sales_data['TotalAmount'], errors='coerce')
sales_data['DiscountApplied'] = sales_data['UnitTotal'] > sales_data['TotalAmount']
print(sales_data)
# Out:
#         OrderID  CustomerID CustomerName   Product     Category  Quantity  \
# 0         44770        8192  @ charlie !  Keyboard  Electronics       1.0
# 1         23355        9138  @ charlie !   Monitor  Electronics       5.0
# 2         75847        4098  @ charlie !    Laptop  Accessories       3.0
# 3         95176        2391      @ eva !   Monitor  Electronics       5.0
# 4          1854        8842      @ eva !    Laptop  Accessories       4.0
# ...         ...         ...          ...       ...          ...       ...
# 100095    95426        5376    @ alice !  Keyboard  Electronics       2.0
# 100096    77181        6047    @ alice !  Keyboard  Accessories       5.0
# 100097     7354        2439      @ bob !    Laptop  Electronics       8.0
# 100098    52126        2810    @ alice !  Keyboard  Electronics       7.0
# 100099    80766        5705    @ david !    Tablet  Electronics       1.0
#
#           Price  OrderDate             City Region  Returned  TotalAmount  \
# ...

# %%
#Drop the column DiscountApplied after saving it to a variable
saved_discount = sales_data['DiscountApplied'].copy()
sales = sales_data.drop(columns=['DiscountApplied'])
print(saved_discount)
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 100095    False
# 100096    False
# 100097    False
# 100098    False
# 100099    False
# Name: DiscountApplied, Length: 100100, dtype: bool

# %%
#Filter all returned orders.
print(sales_data[sales_data["Returned"]==True])
# Out:
#         OrderID  CustomerID CustomerName   Product     Category  Quantity  \
# 7         79506        3389    @ alice !     Phone  Accessories       9.0
# 15         5103        1382      @ eva !     Phone  Accessories       1.0
# 21        87250        2818    @ alice !     Phone  Electronics       3.0
# 31        81349        3421      @ eva !    Laptop  Accessories       7.0
# 53        50549        8174      @ eva !   Monitor  Electronics       5.0
# ...         ...         ...          ...       ...          ...       ...
# 100031    53849        7723    @ alice !  Keyboard  Electronics       4.0
# 100041    94461        5550  @ charlie !  Keyboard  Electronics       7.0
# 100061    48148        6197      @ bob !    Tablet  Accessories       3.0
# 100094    40937        2341      @ eva !    Tablet  Accessories       4.0
# 100096    77181        6047    @ alice !  Keyboard  Accessories       5.0
#
#           Price  OrderDate             City Region  Returned  TotalAmount  \
# ...

# %%
#Top 5 cities by number of orders
top_cities = sales_data['City'].value_counts().head(5)
print(top_cities)
# Out:
# City
# NEW YORK#123       19781
# PHOENIX#123        19771
# CHICAGO#123        19615
# LOS ANGELES#123    19519
# HOUSTON#123        19412
# Name: count, dtype: int64

# %%
#Top 3 most sold products (by quantity)
result=sales_data.groupby("Product")["Quantity"].sum().sort_values(ascending=False).head(3)
print(result)
# Out:
# Product
# Phone       97697.0
# Laptop      97501.0
# Keyboard    96835.0
# Name: Quantity, dtype: float64

# %%
#Rename CustomerName to CustName and revert it
sales_data.rename(columns={'CustomerName': 'CustName'}, inplace=True)
print("before rename---",sales_data)
# revert back
rev_back=sales_data.rename(columns={'CustName': 'CustomerName'}, inplace=True)
print("after reverting back--- ",sales_data)
# Out:
# before rename---         OrderID  CustomerID     CustName   Product     Category  Quantity  \
# 0         44770        8192  @ charlie !  Keyboard  Electronics       1.0
# 1         23355        9138  @ charlie !   Monitor  Electronics       5.0
# 2         75847        4098  @ charlie !    Laptop  Accessories       3.0
# 3         95176        2391      @ eva !   Monitor  Electronics       5.0
# 4          1854        8842      @ eva !    Laptop  Accessories       4.0
# ...         ...         ...          ...       ...          ...       ...
# 100095    95426        5376    @ alice !  Keyboard  Electronics       2.0
# 100096    77181        6047    @ alice !  Keyboard  Accessories       5.0
# 100097     7354        2439      @ bob !    Laptop  Electronics       8.0
# 100098    52126        2810    @ alice !  Keyboard  Electronics       7.0
# 100099    80766        5705    @ david !    Tablet  Electronics       1.0
#
# ...

# %%
#Check and count missing values in each column
missing_values=sales.isnull().sum()
print(missing_values)
# Out:
# OrderID             0
# CustomerID          0
# CustomerName        0
# Product          2001
# Category         2003
# Quantity         1001
# Price            1001
# OrderDate       20072
# City             2002
# Region              0
# Returned            0
# TotalAmount      1001
# UnitTotal        1001
# dtype: int64

# %%
#Fill missing City values with "Unknown"
sales_data['City'] = sales_data['City'].fillna("Unknown")
print(sales_data["City"])
# Out:
# 0             PHOENIX#123
# 1             HOUSTON#123
# 2            NEW YORK#123
# 3             CHICAGO#123
# 4             CHICAGO#123
#                ...
# 100095            Unknown
# 100096        CHICAGO#123
# 100097    LOS ANGELES#123
# 100098       NEW YORK#123
# 100099        CHICAGO#123
# Name: City, Length: 100100, dtype: object

# %%
#Remove duplicates based on OrderID
sales_data = sales_data.drop_duplicates(subset='OrderID')
print(sales_data["OrderID"])
# Out:
# 0         44770
# 1         23355
# 2         75847
# 3         95176
# 4          1854
#           ...
# 100095    95426
# 100096    77181
# 100097     7354
# 100098    52126
# 100099    80766
# Name: OrderID, Length: 100000, dtype: int64

# %%
#Sort by TotalAmount (descending)
sorted_res=sales_data.sort_values(by='TotalAmount', ascending=False)
print(sorted_res)
# Out:
#        OrderID  CustomerID CustomerName   Product     Category  Quantity  \
# 99875    78404        2864      @ bob !    Laptop  Accessories       9.0
# 47882    27909        1707    @ david !   Monitor  Electronics       9.0
# 75618    63782        7708    @ david !  Keyboard  Electronics       9.0
# 55578    49344        4338    @ david !  Keyboard  Electronics       9.0
# 53794    34029        3759      @ bob !    Laptop  Electronics       9.0
# ...        ...         ...          ...       ...          ...       ...
# 99302     6464        6738    @ david !    Tablet  Electronics       NaN
# 99371    17207        5753  @ charlie !     Phone  Electronics       NaN
# 99529    29355        9833      @ eva !  Keyboard  Accessories       NaN
# 99630    86382        8146      @ bob !     Phone  Electronics       NaN
# 99845    11862        8008      @ eva !    Tablet  Electronics       NaN
#
#          Price  OrderDate             City Region  Returned  TotalAmount  \
# ...

# %%
#Top 5 orders with highest total amount
print(sales.sort_values('TotalAmount', ascending=False).head(5))
# Out:
#        OrderID  CustomerID CustomerName   Product     Category  Quantity  \
# 99875    78404        2864      @ bob !    Laptop  Accessories       9.0
# 47882    27909        1707    @ david !   Monitor  Electronics       9.0
# 75618    63782        7708    @ david !  Keyboard  Electronics       9.0
# 55578    49344        4338    @ david !  Keyboard  Electronics       9.0
# 53794    34029        3759      @ bob !    Laptop  Electronics       9.0
#
#          Price  OrderDate          City Region  Returned  TotalAmount  \
# 99875  1499.99 2024-07-06   PHOENIX#123   West     False     13499.91
# 47882  1499.95 2024-01-28   CHICAGO#123   West     False     13499.55
# 75618  1499.74 2024-06-07  NEW YORK#123   West     False     13497.66
# 55578  1499.20 2023-02-13  NEW YORK#123  South     False     13492.80
# 53794  1499.17        NaT   PHOENIX#123   East     False     13492.53
#
#        UnitTotal
# 99875   13499.91
# 47882   13499.55
# 75618   13497.66
# 55578   13492.80
# ...

# %%
#Extract Year and Month from OrderDate
sales_data['Year'] = sales_data['OrderDate'].dt.year
sales_data['Month'] = sales_data['OrderDate'].dt.month
print(sales_data['Year'],sales_data['Month'])
# Out:
# 0            NaN
# 1         2024.0
# 2         2024.0
# 3            NaN
# 4            NaN
#            ...
# 100095    2023.0
# 100096       NaN
# 100097    2024.0
# 100098    2023.0
# 100099    2023.0
# Name: Year, Length: 100000, dtype: float64 0          NaN
# 1          5.0
# 2         11.0
# 3          NaN
# 4          NaN
#           ...
# 100095     8.0
# 100096     NaN
# 100097    10.0
# 100098    10.0
# 100099     3.0
# Name: Month, Length: 100000, dtype: float64

# %%
#Create a new column OrderMonth with full month name
sales_data['OrderMonth'] = sales_data['OrderDate'].dt.strftime('%B')
print(sales_data["OrderMonth"])
# Out:
# 0              NaN
# 1              May
# 2         November
# 3              NaN
# 4              NaN
#             ...
# 100095      August
# 100096         NaN
# 100097     October
# 100098     October
# 100099       March
# Name: OrderMonth, Length: 100000, dtype: object

# %%
#Show all Q1 (Jan–Mar) orders
q1_orders = sales_data[(sales_data['Month'] >= 1) & (sales_data['Month'] <= 3)]
print(q1_orders)
# Out:
#         OrderID  CustomerID CustomerName   Product     Category  Quantity  \
# 15         5103        1382      @ eva !     Phone  Accessories       1.0
# 21        87250        2818    @ alice !     Phone  Electronics       3.0
# 24        90538        2124    @ david !  Keyboard  Accessories       4.0
# 43        48638        4913  @ charlie !    Tablet  Electronics       3.0
# 49        66090        6049    @ david !  Keyboard  Electronics       6.0
# ...         ...         ...          ...       ...          ...       ...
# 100074    79782        9365    @ david !    Laptop  Accessories       5.0
# 100082    44707        7179  @ charlie !  Keyboard  Electronics       9.0
# 100088    50567        7478  @ charlie !   Monitor  Accessories       3.0
# 100094    40937        2341      @ eva !    Tablet  Accessories       4.0
# 100099    80766        5705    @ david !    Tablet  Electronics       1.0
#
#           Price  OrderDate             City Region  Returned  TotalAmount  \
# ...

# %%
#Number of orders for each region
sales_data['Region'].value_counts()
# Out:
# Region
# East     25098
# North    25022
# South    24998
# West     24882
# Name: count, dtype: int64

# %%
#Customers who bought BOTH "Phone" and "Laptop"
phone_customers = set(sales_data[sales_data['Product'] == 'Phone']['CustomerID'])
laptop_customers = set(sales_data[sales_data['Product'] == 'Laptop']['CustomerID'])
both=phone_customers.intersection(laptop_customers)
print(both)
# Out:
# {1000, 1001, 1003, 1004, 1005, 1006, 1007, 1008, 1010, 1011, 1012, 1013, 1014, 1015, 1016, 1017, 1018, 1019, 1021, 1022, 1023, 1024, 1025, 1026, 1027, 1028, 1030, 1031, 1032, 1033, 1034, 1036, 1037, 1039, 1040, 1041, 1043, 1045, 1048, 1049, 1050, 1051, 1053, 1054, 1055, 1056, 1057, 1058, 1059, 1060, 1061, 1062, 1063, 1064, 1066, 1067, 1068, 1070, 1071, 1072, 1073, 1078, 1079, 1080, 1081, 1082, 1083, 1084, 1085, 1086, 1089, 1090, 1091, 1092, 1095, 1096, 1097, 1098, 1099, 1100, 1101, 1103, 1104, 1106, 1108, 1109, 1110, 1111, 1112, 1113, 1116, 1117, 1118, 1119, 1121, 1122, 1123, 1125, 1126, 1127, 1130, 1132, 1133, 1135, 1137, 1139, 1140, 1141, 1142, 1145, 1146, 1148, 1149, 1150, 1151, 1152, 1153, 1154, 1155, 1157, 1158, 1160, 1161, 1162, 1163, 1164, 1167, 1169, 1170, 1171, 1173, 1177, 1178, 1180, 1181, 1182, 1183, 1184, 1185, 1187, 1188, 1189, 1191, 1192, 1193, 1198, 1200, 1201, 1202, 1203, 1204, 1205, 1206, 1207, 1208, 1209, 1210, 1211, 1213, 1215, 1219, 1220, 1221, 1222, 1223, 1224, 1
# ...

# %%
#Convert all city names to uppercase and restore later
backup_city = sales_data['City'].copy()
sales_data['City'] = sales_data['City'].str.upper()
print(sales_data["City"])

#restore
sales_data['City'] = backup_city
print(sales_data["City"])
# Out:
# 0             PHOENIX#123
# 1             HOUSTON#123
# 2            NEW YORK#123
# 3             CHICAGO#123
# 4             CHICAGO#123
#                ...
# 100095            UNKNOWN
# 100096        CHICAGO#123
# 100097    LOS ANGELES#123
# 100098       NEW YORK#123
# 100099        CHICAGO#123
# Name: City, Length: 100000, dtype: object
# 0             PHOENIX#123
# 1             HOUSTON#123
# 2            NEW YORK#123
# 3             CHICAGO#123
# 4             CHICAGO#123
#                ...
# 100095            UNKNOWN
# 100096        CHICAGO#123
# 100097    LOS ANGELES#123
# 100098       NEW YORK#123
# 100099        CHICAGO#123
# Name: City, Length: 100000, dtype: object

# %%
#Average price of each category
average_price = sales_data.groupby('Category')['Price'].mean()
print(average_price)
# Out:
# Category
# Accessories    801.420981
# Electronics    799.062436
# Name: Price, dtype: float64

# %%
#Total sales by Region (groupby)
sales_sum=sales_data.groupby("Region")["TotalAmount"].sum()
print(sales_sum)
# Out:
# Region
# East     99576789.10
# North    98930659.21
# South    99021836.16
# West     98369402.78
# Name: TotalAmount, dtype: float64

# %%
#Save only East region data to CSV
east_data=sales_data[sales_data["Region"]=="East"]
east_data.to_csv("east_region_data.csv",index=False)

# %%
#Reset and set index using OrderID
sales_reset = sales_data.reset_index()

sales_indexed = sales_data.set_index('OrderID')
print(sales_indexed)
# Out:
#          CustomerID CustomerName   Product     Category  Quantity    Price  \
# OrderID
# 44770          8192  @ charlie !  Keyboard  Electronics       1.0   870.54
# 23355          9138  @ charlie !   Monitor  Electronics       5.0   144.02
# 75847          4098  @ charlie !    Laptop  Accessories       3.0   557.79
# 95176          2391      @ eva !   Monitor  Electronics       5.0   552.20
# 1854           8842      @ eva !    Laptop  Accessories       4.0   411.20
# ...             ...          ...       ...          ...       ...      ...
# 95426          5376    @ alice !  Keyboard  Electronics       2.0   468.67
# 77181          6047    @ alice !  Keyboard  Accessories       5.0  1350.58
# 7354           2439      @ bob !    Laptop  Electronics       8.0   330.46
# 52126          2810    @ alice !  Keyboard  Electronics       7.0   361.90
# 80766          5705    @ david !    Tablet  Electronics       1.0   760.99
#
# ...

# %%
#Display all weekend orders (Saturday & Sunday)
sales['Weekday'] = sales['OrderDate'].dt.weekday  # 0=Mon … 6=Sun
weekend_orders = sales[sales['Weekday'] >= 5]
weekend_orders
# Out:
#         OrderID  CustomerID CustomerName   Product     Category  Quantity  \
# 5         56788        6935    @ david !   Monitor  Electronics       1.0
# 7         79506        3389    @ alice !     Phone  Accessories       9.0
# 8         55148        1287    @ david !    Laptop  Accessories       2.0
# 9         24564        3745      @ bob !    Tablet  Accessories       8.0
# 10        60114        6368    @ alice !    Laptop  Accessories       3.0
# ...         ...         ...          ...       ...          ...       ...
# 100090    87473        6459      @ eva !     Phone  Electronics       7.0
# 100091    46252        4130      @ bob !     Phone  Accessories       7.0
# 100097     7354        2439      @ bob !    Laptop  Electronics       8.0
# 100098    52126        2810    @ alice !  Keyboard  Electronics       7.0
# 100099    80766        5705    @ david !    Tablet  Electronics       1.0
#
#          Price  OrderDate             City Region  Returned  TotalAmount  \
# ...

# %%
#Create a pivot table of TotalAmount by Region and Category
pivot_region_category = sales_data.pivot_table(
    values='TotalAmount',
    index='Region',
    columns='Category',
    aggfunc='sum',
    fill_value=0
)
pivot_region_category
# Out:
# Category  Accessories  Electronics
# Region
# East      48596869.16  49141938.16
# North     48243633.69  48498063.95
# South     48628318.04  48338803.01
# West      48250060.38  48238382.34

# %%
#Unpivot (melt) the pivot table from Task 31
melted = pivot_region_category.reset_index().melt(
    id_vars='Region',
    var_name='Category',
    value_name='TotalAmount'
)
melted
# Out:
#   Region     Category  TotalAmount
# 0   East  Accessories  48596869.16
# 1  North  Accessories  48243633.69
# 2  South  Accessories  48628318.04
# 3   West  Accessories  48250060.38
# 4   East  Electronics  49141938.16
# 5  North  Electronics  48498063.95
# 6  South  Electronics  48338803.01
# 7   West  Electronics  48238382.34

# %%
#Use groupby() to get average Price by Product and Region
avg_price_prod_region = sales.groupby(['Product', 'Region'])['Price'].mean()
avg_price_prod_region
# Out:
# Product   Region
# Keyboard  East      792.978739
#           North     800.111859
#           South     802.419370
#           West      792.614988
# Laptop    East      804.949776
#           North     814.811398
#           South     801.517062
#           West      793.726967
# Monitor   East      802.803601
#           North     788.955842
#           South     793.167280
#           West      803.838535
# Phone     East      793.719012
#           North     800.904670
#           South     805.499545
#           West      800.988814
# Tablet    East      811.730826
#           North     807.827802
#           South     798.652803
#           West      796.095443
# Name: Price, dtype: float64

# %%
#Use .agg() to get min, max, mean Quantity for each Category
qty_stats_by_category = sales.groupby('Category')['Quantity'].agg(['min', 'max', 'mean'])
qty_stats_by_category
# Out:
#              min  max      mean
# Category
# Accessories  1.0  9.0  4.995743
# Electronics  1.0  9.0  4.979949

# %%
#Create a lookup table for CustomerID and CustomerName and remove duplicates
customer_lookup = sales_data[['CustomerID', 'CustomerName']].drop_duplicates()
customer_lookup
# Out:
#         CustomerID CustomerName
# 0             8192  @ charlie !
# 1             9138  @ charlie !
# 2             4098  @ charlie !
# 3             2391      @ eva !
# 4             8842      @ eva !
# ...            ...          ...
# 100029        8276      @ bob !
# 100054        4222      @ eva !
# 100081        8960      @ bob !
# 100089        6732      @ eva !
# 100092        5466      @ eva !
#
# [40134 rows x 2 columns]

# %%
#Create a lookup for Product and Category, remove duplicates
product_lookup = sales_data[['Product', 'Category']].drop_duplicates()
product_lookup
# Out:
#        Product     Category
# 0     Keyboard  Electronics
# 1      Monitor  Electronics
# 2       Laptop  Accessories
# 6       Tablet  Electronics
# 7        Phone  Accessories
# 9       Tablet  Accessories
# 11      Laptop  Electronics
# 14    Keyboard  Accessories
# 21       Phone  Electronics
# 32     Monitor  Accessories
# 77     Monitor          NaN
# 95         NaN  Accessories
# 127        NaN  Electronics
# 132     Tablet          NaN
# 151   Keyboard          NaN
# 240     Laptop          NaN
# 717      Phone          NaN
# 2207       NaN          NaN

# %%
#Merge back the lookups with the main file (simulate master lookup join)
merged_data = pd.merge(sales_data, customer_lookup, on='CustomerID', how='left')
merged_data = pd.merge(merged_data, product_lookup, on='Product', how='left')
merged_data
# Out:
#          OrderID  CustomerID CustomerName_x   Product   Category_x  Quantity  \
# 0          44770        8192    @ charlie !  Keyboard  Electronics       1.0
# 1          44770        8192    @ charlie !  Keyboard  Electronics       1.0
# 2          44770        8192    @ charlie !  Keyboard  Electronics       1.0
# 3          44770        8192    @ charlie !  Keyboard  Electronics       1.0
# 4          44770        8192    @ charlie !  Keyboard  Electronics       1.0
# ...          ...         ...            ...       ...          ...       ...
# 1369468    80766        5705      @ david !    Tablet  Electronics       1.0
# 1369469    80766        5705      @ david !    Tablet  Electronics       1.0
# 1369470    80766        5705      @ david !    Tablet  Electronics       1.0
# 1369471    80766        5705      @ david !    Tablet  Electronics       1.0
# 1369472    80766        5705      @ david !    Tablet  Electronics       1.0
#
# ...

# %%
#Calculate return rate % by region
return_rate_by_region = sales_data.groupby('Region')['Returned'].mean() * 100
return_rate_by_region
# Out:
# Region
# East     10.092438
# North     9.783391
# South     9.752780
# West      9.826381
# Name: Returned, dtype: float64

# %%
#Create a new column DiscountedPrice assuming a flat 10% discount on all products
sales_data['DiscountedPrice'] = sales_data['Price'] * 0.9
sales_data
# Out:
#         OrderID  CustomerID CustomerName   Product     Category  Quantity  \
# 0         44770        8192  @ charlie !  Keyboard  Electronics       1.0
# 1         23355        9138  @ charlie !   Monitor  Electronics       5.0
# 2         75847        4098  @ charlie !    Laptop  Accessories       3.0
# 3         95176        2391      @ eva !   Monitor  Electronics       5.0
# 4          1854        8842      @ eva !    Laptop  Accessories       4.0
# ...         ...         ...          ...       ...          ...       ...
# 100095    95426        5376    @ alice !  Keyboard  Electronics       2.0
# 100096    77181        6047    @ alice !  Keyboard  Accessories       5.0
# 100097     7354        2439      @ bob !    Laptop  Electronics       8.0
# 100098    52126        2810    @ alice !  Keyboard  Electronics       7.0
# 100099    80766        5705    @ david !    Tablet  Electronics       1.0
#
#           Price  OrderDate             City Region  Returned  TotalAmount  \
# ...

# %%
#Calculate the cumulative revenue for each Region sorted by OrderDate
sales_data = sales_data.sort_values(['Region', 'OrderDate'])
sales_data['CumulativeRevenue'] = sales_data.groupby('Region')['TotalAmount'].cumsum()
sales_data['CumulativeRevenue']
# Out:
# 6766           778.08
# 11608         7677.54
# 13730        11979.90
# 17594        14834.78
# 17652        17252.90
#              ...
# 99997     98358302.98
# 100013    98362231.27
# 100048    98362741.59
# 100080    98363837.63
# 100084    98369402.78
# Name: CumulativeRevenue, Length: 100000, dtype: float64

# %%
#Rank customers by their total revenue generated (TotalAmount) in descending order
customer_rank = sales_data.groupby('CustomerID')['TotalAmount'].sum().reset_index()
customer_rank['Rank'] = customer_rank['TotalAmount'].rank(ascending=False, method='min')
customer_rank.head(20)
# Out:
#     CustomerID  TotalAmount    Rank
# 0         1000     46434.37  3652.0
# 1         1001     43657.82  4234.0
# 2         1002     26351.27  7735.0
# 3         1003     40095.51  5022.0
# 4         1004     20623.99  8388.0
# 5         1005     48673.73  3196.0
# 6         1006     58988.01  1618.0
# 7         1007     44664.16  4006.0
# 8         1008     27927.57  7511.0
# 9         1009     37690.88  5579.0
# 10        1010     41778.69  4649.0
# 11        1011     74857.04   421.0
# 12        1012     46828.70  3565.0
# 13        1013     39714.72  5109.0
# 14        1014     41252.53  4770.0
# 15        1015     24963.22  7937.0
# 16        1016     62266.72  1274.0
# 17        1017     42515.72  4475.0
# 18        1018     50271.35  2899.0
# 19        1019     37375.26  5654.0

# %%
#Calculate the average order value per customer using groupby()
average_order_value = sales_data.groupby('CustomerID')['TotalAmount'].mean()
average_order_value
# Out:
# CustomerID
# 1000    3316.740714
# 1001    2728.613750
# 1002    3293.908750
# 1003    2863.965000
# 1004    2291.554444
#            ...
# 9994    4331.444375
# 9995    4778.646190
# 9996    4078.016364
# 9997    4062.555000
# 9998    5318.008421
# Name: TotalAmount, Length: 8999, dtype: float64

# %%
#Generate a report showing total quantity sold per Category per Region
quantity_report = sales_data.groupby(['Region', 'Category'])['Quantity'].sum().reset_index()
quantity_report
# Out:
#   Region     Category  Quantity
# 0   East  Accessories   60655.0
# 1   East  Electronics   61020.0
# 2  North  Accessories   60266.0
# 3  North  Electronics   60393.0
# 4  South  Accessories   60689.0
# 5  South  Electronics   60429.0
# 6   West  Accessories   59860.0
# 7   West  Electronics   60548.0

# %%
#Use .agg() to compute multiple stats (sum, mean, min, max) for TotalAmount per Region
region_stats = sales.groupby('Region')['TotalAmount'].agg(['sum','mean','min','max']).reset_index()
region_stats
# Out:
#   Region          sum         mean     min       max
# 0   East  99725660.81  4007.460752  100.07  13492.53
# 1  North  99066474.71  3997.839980  100.19  13491.45
# 2  South  99089901.41  4001.368980  101.10  13492.80
# 3   West  98470580.60  3991.511171  100.34  13499.91

# %%
#Create a summary DataFrame showing each customer’s: total orders, total amount spent, and total products bought
customer_summary = sales_data.groupby('CustomerID').agg(
    TotalOrders=('OrderID', 'nunique'),
    TotalAmount=('TotalAmount', 'sum'),
    TotalProducts=('Quantity', 'sum')
).reset_index()
customer_summary
# Out:
#       CustomerID  TotalOrders  TotalAmount  TotalProducts
# 0           1000           14     46434.37           61.0
# 1           1001           16     43657.82           71.0
# 2           1002            8     26351.27           38.0
# 3           1003           14     40095.51           60.0
# 4           1004            9     20623.99           39.0
# ...          ...          ...          ...            ...
# 8994        9994           16     69303.11           71.0
# 8995        9995           21    100351.57          111.0
# 8996        9996           11     44858.18           53.0
# 8997        9997            8     32500.44           42.0
# 8998        9998           20    101042.16          111.0
#
# [8999 rows x 4 columns]

# %%
#onvert OrderDate to datetime and extract Year, Month, and Weekday
sales['OrderDate'] = pd.to_datetime(sales['OrderDate'])
sales['Year'] = sales['OrderDate'].dt.year
sales['Month'] = sales['OrderDate'].dt.month
sales['Weekday'] = sales['OrderDate'].dt.day_name()
sales[['OrderDate','Year','Month','Weekday']].head(10)
# Out:
#    OrderDate    Year  Month    Weekday
# 0        NaT     NaN    NaN        NaN
# 1 2024-05-02  2024.0    5.0   Thursday
# 2 2024-11-08  2024.0   11.0     Friday
# 3        NaT     NaN    NaN        NaN
# 4        NaT     NaN    NaN        NaN
# 5 2024-10-06  2024.0   10.0     Sunday
# 6 2024-04-03  2024.0    4.0  Wednesday
# 7 2024-07-14  2024.0    7.0     Sunday
# 8 2024-09-01  2024.0    9.0     Sunday
# 9 2023-04-23  2023.0    4.0     Sunday

# %%
#Extract only the first name from CustomerName
sales_data['FirstName'] = sales_data['CustomerName'].str.split().str[0]
sales_data['FirstName']
# Out:
# 6766      @
# 11608     @
# 13730     @
# 17594     @
# 17652     @
#          ..
# 99997     @
# 100013    @
# 100048    @
# 100080    @
# 100084    @
# Name: FirstName, Length: 100000, dtype: object

# %%
#Extract only the first name from CustomerName
sales_data['FirstName'] = sales_data['CustomerName'].str.split().str[0]
sales_data['FirstName']
# Out:
# 6766      @
# 11608     @
# 13730     @
# 17594     @
# 17652     @
#          ..
# 99997     @
# 100013    @
# 100048    @
# 100080    @
# 100084    @
# Name: FirstName, Length: 100000, dtype: object

# %%
#Create HighValueOrder where TotalAmount > 5000
sales_data['HighValueOrder'] = sales_data['TotalAmount'] > 5000
sales_data['HighValueOrder']
# Out:
# 6766      False
# 11608      True
# 13730     False
# 17594     False
# 17652     False
#           ...
# 99997     False
# 100013    False
# 100048    False
# 100080    False
# 100084     True
# Name: HighValueOrder, Length: 100000, dtype: bool

# %%
#Analyze & visualize top 5 customers and top 5 products contributing to revenue using master file

top_customers = sales_data.groupby('CustomerName')['TotalAmount'].sum().sort_values(ascending=False).head(5).reset_index()
top_products = sales_data.groupby('Product')['TotalAmount'].sum().sort_values(ascending=False).head(5).reset_index()
top_customers, top_products
# Out:
# (  CustomerName  TotalAmount
#  0      @ bob !  80792023.58
#  1      @ eva !  79699296.25
#  2    @ alice !  78661034.98
#  3    @ david !  78453964.56
#  4  @ charlie !  78292367.88,
#      Product  TotalAmount
#  0    Laptop  78531807.54
#  1     Phone  78132514.71
#  2    Tablet  77839753.89
#  3  Keyboard  77172965.77
#  4   Monitor  76437165.84)
